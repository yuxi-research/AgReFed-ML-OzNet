# %% [markdown]
# Model selection and cross-validation for soil moisture mapping
# ---------------------------------------------------------------
#
# This notebook trains multiple models for soil moisture prediction maps.
# The model training data is based on weekly averaged soil moisture probes and multiple spatial-temporal dependent covariates.
#
# The prediction models that are tested are based on Gaussian Process regression with two different base function: Random Forest (RF) and Bayesian Linear Regression (BLR). The base functions are used to account for the non-linear relationship between the covariates and the soil moisture. Gaussian Process Regression (GPR) is used to account for the spatial-temporal correlation of the soil moisture probes. When GPR is enabled, base model were used as the mean function of GPR.
#
# The model selection is based on the cross-validation of the prediction error (normalized RMSE, R2) for the test data.
# Test data is selected based on n-fold cross-validation. Different test data is selected for each fold.
#
# Note that test data is n-fold split based on the spatial location of the probes, and not on time. If test data would be selected based on unique location in space and time rather than on space only, the cross-validation would reveal in superficial low prediction errors, because the temporal variability of the soil moisture over short time periods is very low relative to the spatial variations, and hence test data would be strongly correlated with the training data.
#
# User settings, such as input/output paths and all other options, are set in the settings file, e.g.:
#
# `settings_testmodel_spatial.yaml`
#
# This package is part of the machine learning project developed for the Agricultural Research Federation (AgReFed).

# %% [markdown]
# Model selection and cross-validation for soil moisture mapping
# ---------------------------------------------------------------
#
# This notebook trains multiple models for soil moisture prediction maps.
# The model training data is based on weekly averaged soil moisture probes and multiple spatial-temporal dependent covariates.
#
# The prediction models that are tested are based on Gaussian Process regression with two different base function: Random Forest (RF) and Bayesian Linear Regression (BLR). The base functions are used to account for the non-linear relationship between the covariates and the soil moisture. Gaussian Process Regression (GPR) is used to account for the spatial-temporal correlation of the soil moisture probes. When GPR is enabled, base model were used as the mean function of GPR.
#
# The model selection is based on the cross-validation of the prediction error (normalized RMSE, R2) for the test data.
# Test data is selected based on n-fold cross-validation. Different test data is selected for each fold.
#
# Note that test data is n-fold split based on the spatial location of the probes, and not on time. If test data would be selected based on unique location in space and time rather than on space only, the cross-validation would reveal in superficial low prediction errors, because the temporal variability of the soil moisture over short time periods is very low relative to the spatial variations, and hence test data would be strongly correlated with the training data.
#
# User settings, such as input/output paths and all other options, are set in the settings file, e.g.:
#
# `settings_testmodel_spatial.yaml`
#
# This package is part of the machine learning project developed for the Agricultural Research Federation (AgReFed).

# %% [markdown]
# ## Library imports

# %%
import numpy as np
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import yaml
import argparse
from types import SimpleNamespace  
from matplotlib.image import imread
import time

# Custom local libraries:
sys.path.append('../../python_scripts')

from utils import print2, truncate_data
from preprocessing import gen_kfold_st
import GPmodel as gp # GP model plus kernel functions and distance matrix calculation
import model_blr as blr
import model_rf as rf
from soilmod_xval_gapfill import runmodel

# %% [markdown]
#  ## Reading and process settings
#
#  All settings are specified in the .yaml file to make analysis reproducible. Below we will read and inspect the settings.

# %%
# Define name of settings file to save configuration
fname_settings = 'settings_testmodel_gapfill.yaml'
path_settings = '.'

# %%
# Load settings from yaml file
with open(os.path.join(path_settings,fname_settings), 'r') as f:
    settings = yaml.load(f, Loader=yaml.FullLoader)
# Parse settings dictinary as namespace (settings are available as 
# settings.variable_name rather than settings['variable_name'])
settings = SimpleNamespace(**settings)


# Add temporal or vertical component
if settings.axistype == 'temporal':
    settings.colname_zcoord = settings.colname_tcoord
    settings.colname_zmin = settings.colname_tmin
    settings.colname_zmax =  settings.colname_tmax

if type(settings.model_functions) != list:
    settings.model_functions = [settings.model_functions]

# check if outpath exists, if not create direcory
os.makedirs(settings.outpath, exist_ok = True)

# Intialise output info file:
print('init')
print(f'--- Parameter Settings ---')
print(f'Selected Model Functions: {settings.model_functions}')
print(f'Target Name: {settings.name_target}')
print(f'--------------------------')

# Print features selected
print("")
print("--- Features Selected ---")
for key in settings.__dict__:
    if key == "name_features":
        for feature in settings.name_features:
            print(f"'{feature}'")
# Out:
# init
# --- Parameter Settings ---
# Selected Model Functions: ['rf', 'blr', 'xgb']
# Target Name: SM
# --------------------------
#
# --- Features Selected ---
# 'NDVI'
# 'SND'
# 'CLY'
# 'L15'
# 'DepthBot'
# 'BDW'
# 'SOC'
# 'DepthTop'
# 'PAWC'
# 'Rain_df_950'
# 'Solar'
# 'ET_df_990'

# %% [markdown]
# ## Data Preprocessing
#
# The data preprocessing includes the following steps:
#  - reading in the dataset from .csv file into pandas dataframe
#  - checking coordinate names and converting if necessary to default name convention (x,y,z)
#  - select data for top soil only
#  - generating n-fold cross-validation test sets
#  - converting coordinates to origin at x,y = 0,0

# %%
print('Reading data into dataframe...')
# Read in data
dfsel = pd.read_csv(os.path.join(settings.inpath, settings.infname))

# Rename x and y coordinates of input data
if settings.colname_xcoord != 'x':
    dfsel.rename(columns={settings.colname_xcoord: 'x'}, inplace = True)
if settings.colname_ycoord != 'y':
    dfsel.rename(columns={settings.colname_ycoord: 'y'}, inplace = True)
if (settings.axistype == 'vertical') & (settings.colname_zcoord != 'z'):
    dfsel.rename(columns={settings.colname_zcoord: 'z'}, inplace = True)
else:
    dfsel.rename(columns={settings.colname_tcoord: 'z'}, inplace = True)
    dfsel.rename(columns={settings.colname_zcoord: 'z'}, inplace = True)
settings.name_features.append('z')

# Select data between zmin and zmax
dfsel = dfsel[(dfsel['z'] >= settings.colname_zmin) & (dfsel['z'] <= settings.colname_zmax)]

# Generate n-fold indices
print(f'Generating {settings.nfold_s}_{settings.nfold_t}-fold test sets based on moisture probe locations..')
# dfsel = gen_kfold(dfsel, nfold = settings.nfold, label_nfold = 'nfold', id_unique = ['z'], precision_unique = 0.01, sort=True)
dfsel = gen_kfold_st(dfsel, nfold_s = settings.nfold_s, nfold_t = settings.nfold_t)

## Get coordinates for training data and set coord origin to (0,0)
print(f'Setting coordinate origin to (0,0)...')
bound_xmin = dfsel.x.min()
bound_xmax = dfsel.x.max()
bound_ymin = dfsel.y.min()
bound_ymax = dfsel.y.max()
 
# Set origin to (0,0)
dfsel['x'] = dfsel['x'] - bound_xmin
dfsel['y'] = dfsel['y'] - bound_ymin

print('Preprocessing data finished.')
# Out:
# Reading data into dataframe...
# Generating 5_3-fold test sets based on moisture probe locations..
# Setting coordinate origin to (0,0)...
# Preprocessing data finished.

# %% [markdown]
# ## Train and test multiple models
#
# Here we train and test multiple models as specified in the settings: settings.model_functions.
# The models are a combination of Gaussian Process regression with either a Random Forest or Bayesian linear regression model as base function.
#
# This training step will take a couple of minutes given that a new model needs to be trained and evaluated for each cross-validation and model type.
#
# The results for each model are saved as:
# - RMSE:  root mean squared error
# - NRMSE: normalized RMSE to standard deviation
# - NRMedSE: normalized root median SE
# - ubRMSE: unbiased RMSE
# - r: Pearson correlation coefficient
# - r2: square of Pearon's r
# - R2: coefficient of determination
# - LCCC: Lin's concordance correlation coefficient
# - NSE: Nash-Sutcliffe efficiency
# - Theta: Mean ratio of true error squared divided by predicted error squared for test data

# %%
# Define stats result lists
stats_summaries = []

# Loop over model functions and evaluate
for model_function in settings.model_functions:
    # run and evaluate model
    time_start = time.time()
    dfsum, stats_summary, model_outpath = runmodel(dfsel, model_function, settings)
    time_end = time.time()
    print(f'Time elapsed: {(time_end - time_start)/3600} hours.)')
    print(f'All output files of {model_function} saved in {model_outpath}')
    print('')
    # save results
    stats_summaries.append(stats_summary)
# Out:
# Computing 5_3-fold xrossvalidation for function model: rf
# Processing for nfold  1 1
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0198
# Bias:  -0.0029
# RMSE:  0.0256
# Normalized RMSE:  0.3233
# Normalized ROOT MEDIAN SE:  0.1972
# Unbiased RMSE:  0.0254
# r:  0.9489
# r^2:  0.9004
# R^2:  0.8955
# Lin's CCC:  0.9424
# Nash Sutcliffe Efficiency:  0.8955
# Mean Theta:  0.4116
# Median Theta:  0.0
# Processing for nfold  1 2
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0266
# Bias:  -0.003
# RMSE:  0.0361
# Normalized RMSE:  0.4621
# Normalized ROOT MEDIAN SE:  0.2335
# Unbiased RMSE:  0.036
# r:  0.8877
# r^2:  0.788
# R^2:  0.7865
# Lin's CCC:  0.8824
# Nash Sutcliffe Efficiency:  0.7865
# Mean Theta:  1.0801
# Median Theta:  1.0
# Processing for nfold  1 3
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0176
# Bias:  0.0022
# RMSE:  0.024
# Normalized RMSE:  0.3002
# Normalized ROOT MEDIAN SE:  0.1695
# Unbiased RMSE:  0.0239
# r:  0.9564
# r^2:  0.9147
# R^2:  0.9099
# Lin's CCC:  0.9502
# Nash Sutcliffe Efficiency:  0.9099
# Mean Theta:  0.3161
# Median Theta:  0.0
# Processing for nfold  2 1
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0187
# Bias:  -0.0006
# RMSE:  0.0233
# Normalized RMSE:  0.2117
# Normalized ROOT MEDIAN SE:  0.1428
# Unbiased RMSE:  0.0233
# r:  0.9816
# r^2:  0.9635
# R^2:  0.9552
# Lin's CCC:  0.975
# Nash Sutcliffe Efficiency:  0.9552
# Mean Theta:  0.4322
# Median Theta:  0.0
# Processing for nfold  2 2
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0164
# Bias:  0.0028
# RMSE:  0.0202
# Normalized RMSE:  0.1944
# Normalized ROOT MEDIAN SE:  0.1322
# Unbiased RMSE:  0.02
# r:  0.982
# r^2:  0.9644
# R^2:  0.9622
# Lin's CCC:  0.9804
# Nash Sutcliffe Efficiency:  0.9622
# Mean Theta:  0.3988
# Median Theta:  0.0
# Processing for nfold  2 3
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0197
# Bias:  -0.0081
# RMSE:  0.0269
# Normalized RMSE:  0.2608
# Normalized ROOT MEDIAN SE:  0.1387
# Unbiased RMSE:  0.0257
# r:  0.969
# r^2:  0.9389
# R^2:  0.932
# Lin's CCC:  0.9671
# Nash Sutcliffe Efficiency:  0.932
# Mean Theta:  0.5156
# Median Theta:  0.0
# Processing for nfold  3 1
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0277
# Bias:  -0.0072
# RMSE:  0.0325
# Normalized RMSE:  0.3673
# Normalized ROOT MEDIAN SE:  0.2879
# Unbiased RMSE:  0.0317
# r:  0.9562
# r^2:  0.9144
# R^2:  0.8651
# Lin's CCC:  0.9179
# Nash Sutcliffe Efficiency:  0.8651
# Mean Theta:  0.6303
# Median Theta:  0.0
# Processing for nfold  3 2
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0227
# Bias:  0.0023
# RMSE:  0.0331
# Normalized RMSE:  0.384
# Normalized ROOT MEDIAN SE:  0.1648
# Unbiased RMSE:  0.033
# r:  0.9242
# r^2:  0.8541
# R^2:  0.8525
# Lin's CCC:  0.9184
# Nash Sutcliffe Efficiency:  0.8525
# Mean Theta:  0.7856
# Median Theta:  0.0
# Processing for nfold  3 3
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0261
# Bias:  0.0133
# RMSE:  0.0347
# Normalized RMSE:  0.3972
# Normalized ROOT MEDIAN SE:  0.2446
# Unbiased RMSE:  0.0321
# r:  0.9349
# r^2:  0.8741
# R^2:  0.8422
# Lin's CCC:  0.9213
# Nash Sutcliffe Efficiency:  0.8422
# Mean Theta:  0.6489
# Median Theta:  0.0
# Processing for nfold  4 1
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0188
# Bias:  0.0043
# RMSE:  0.0255
# Normalized RMSE:  0.2602
# Normalized ROOT MEDIAN SE:  0.1356
# Unbiased RMSE:  0.0252
# r:  0.9691
# r^2:  0.9391
# R^2:  0.9323
# Lin's CCC:  0.9636
# Nash Sutcliffe Efficiency:  0.9323
# Mean Theta:  0.4549
# Median Theta:  0.0
# Processing for nfold  4 2
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0188
# Bias:  -0.0016
# RMSE:  0.0275
# Normalized RMSE:  0.2891
# Normalized ROOT MEDIAN SE:  0.1319
# Unbiased RMSE:  0.0275
# r:  0.9587
# r^2:  0.9191
# R^2:  0.9164
# Lin's CCC:  0.9545
# Nash Sutcliffe Efficiency:  0.9164
# Mean Theta:  0.7898
# Median Theta:  0.0
# Processing for nfold  4 3
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0197
# Bias:  -0.0045
# RMSE:  0.0264
# Normalized RMSE:  0.2814
# Normalized ROOT MEDIAN SE:  0.1508
# Unbiased RMSE:  0.026
# r:  0.961
# r^2:  0.9236
# R^2:  0.9208
# Lin's CCC:  0.9591
# Nash Sutcliffe Efficiency:  0.9208
# Mean Theta:  0.6179
# Median Theta:  0.0
# Processing for nfold  5 1
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0256
# Bias:  0.0062
# RMSE:  0.0317
# Normalized RMSE:  0.3624
# Normalized ROOT MEDIAN SE:  0.2618
# Unbiased RMSE:  0.0311
# r:  0.9474
# r^2:  0.8975
# R^2:  0.8687
# Lin's CCC:  0.9225
# Nash Sutcliffe Efficiency:  0.8687
# Mean Theta:  0.8723
# Median Theta:  0.0
# Processing for nfold  5 2
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0248
# Bias:  -0.014
# RMSE:  0.0354
# Normalized RMSE:  0.4278
# Normalized ROOT MEDIAN SE:  0.2093
# Unbiased RMSE:  0.0325
# r:  0.9271
# r^2:  0.8595
# R^2:  0.817
# Lin's CCC:  0.9262
# Nash Sutcliffe Efficiency:  0.817
# Mean Theta:  1.9069
# Median Theta:  1.0
# Processing for nfold  5 3
# Using default hyperparameters for Random Forest
# {'n_estimators': 1000, 'max_depth': None, 'max_features': 0.3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# MAE:  0.0261
# Bias:  0.0064
# RMSE:  0.0325
# Normalized RMSE:  0.3508
# Normalized ROOT MEDIAN SE:  0.2514
# Unbiased RMSE:  0.0319
# r:  0.9526
# r^2:  0.9075
# R^2:  0.8769
# Lin's CCC:  0.9273
# Nash Sutcliffe Efficiency:  0.8769
# Mean Theta:  0.7201
# Median Theta:  0.0
# Saving all predictions in dataframe ...
# ---- X-validation Summary -----
# Mean MAE: 0.022 +/- 0.004
# Mean Bias: -0.0 +/- 0.007
# Mean RMSE: 0.029 +/- 0.005
# Mean unbiased RMSE: 0.028 +/- 0.004
# Mean normalized RMSE: 0.325 +/- 0.075
# Median normalized RMSE: 0.169
# Mean r: 0.95 +/- 0.024
# Mean r^2: 0.904
# Mean R^2: 0.889
# Mean LCCC: 0.941
# Mean NSE: 0.889
# Mean Theta: 0.705 +/- 0.378
# Time elapsed: 0.13855144600073496 hours.)
# All output files of rf saved in results_testmodel_gapfill/Xval_5_3-fold_rf_SM
#
# Computing 5_3-fold xrossvalidation for function model: blr
# Processing for nfold  1 1
# MAE:  0.0369
# Bias:  0.0129
# RMSE:  0.0466
# Normalized RMSE:  0.5891
# Normalized ROOT MEDIAN SE:  0.3756
# Unbiased RMSE:  0.0448
# r:  0.852
# r^2:  0.7259
# R^2:  0.6529
# Lin's CCC:  0.8502
# Nash Sutcliffe Efficiency:  0.6529
# Mean Theta:  1.3584
# Median Theta:  1.0
# Processing for nfold  1 2
# MAE:  0.0406
# Bias:  0.0075
# RMSE:  0.0511
# Normalized RMSE:  0.6538
# Normalized ROOT MEDIAN SE:  0.421
# Unbiased RMSE:  0.0506
# r:  0.8441
# r^2:  0.7124
# R^2:  0.5725
# Lin's CCC:  0.8295
# Nash Sutcliffe Efficiency:  0.5725
# Mean Theta:  1.6653
# Median Theta:  1.0
# Processing for nfold  1 3
# MAE:  0.0306
# Bias:  0.0033
# RMSE:  0.0399
# Normalized RMSE:  0.4997
# Normalized ROOT MEDIAN SE:  0.2972
# Unbiased RMSE:  0.0398
# r:  0.8825
# r^2:  0.7788
# R^2:  0.7503
# Lin's CCC:  0.8816
# Nash Sutcliffe Efficiency:  0.7503
# Mean Theta:  0.9756
# Median Theta:  0.0
# Processing for nfold  2 1
# MAE:  0.0286
# Bias:  -0.0034
# RMSE:  0.0342
# Normalized RMSE:  0.3111
# Normalized ROOT MEDIAN SE:  0.251
# Unbiased RMSE:  0.034
# r:  0.9751
# r^2:  0.9508
# R^2:  0.9032
# Lin's CCC:  0.9392
# Nash Sutcliffe Efficiency:  0.9032
# Mean Theta:  0.7031
# Median Theta:  0.0
# Processing for nfold  2 2
# MAE:  0.0235
# Bias:  -0.0005
# RMSE:  0.0294
# Normalized RMSE:  0.2833
# Normalized ROOT MEDIAN SE:  0.1926
# Unbiased RMSE:  0.0294
# r:  0.967
# r^2:  0.935
# R^2:  0.9197
# Lin's CCC:  0.9531
# Nash Sutcliffe Efficiency:  0.9197
# Mean Theta:  0.5132
# Median Theta:  0.0
# Processing for nfold  2 3
# MAE:  0.0263
# Bias:  -0.003
# RMSE:  0.0328
# Normalized RMSE:  0.3177
# Normalized ROOT MEDIAN SE:  0.2074
# Unbiased RMSE:  0.0327
# r:  0.9669
# r^2:  0.9349
# R^2:  0.899
# Lin's CCC:  0.9377
# Nash Sutcliffe Efficiency:  0.899
# Mean Theta:  0.6422
# Median Theta:  0.0
# Processing for nfold  3 1
# MAE:  0.0407
# Bias:  -0.0013
# RMSE:  0.0481
# Normalized RMSE:  0.5428
# Normalized ROOT MEDIAN SE:  0.4302
# Unbiased RMSE:  0.048
# r:  0.8424
# r^2:  0.7096
# R^2:  0.7053
# Lin's CCC:  0.8168
# Nash Sutcliffe Efficiency:  0.7053
# Mean Theta:  1.4587
# Median Theta:  1.0
# Processing for nfold  3 2
# MAE:  0.0385
# Bias:  -0.0025
# RMSE:  0.0475
# Normalized RMSE:  0.5517
# Normalized ROOT MEDIAN SE:  0.3765
# Unbiased RMSE:  0.0475
# r:  0.8351
# r^2:  0.6974
# R^2:  0.6956
# Lin's CCC:  0.8266
# Nash Sutcliffe Efficiency:  0.6956
# Mean Theta:  1.4302
# Median Theta:  1.0
# Processing for nfold  3 3
# MAE:  0.0361
# Bias:  -0.0093
# RMSE:  0.0437
# Normalized RMSE:  0.4995
# Normalized ROOT MEDIAN SE:  0.3844
# Unbiased RMSE:  0.0427
# r:  0.8768
# r^2:  0.7688
# R^2:  0.7505
# Lin's CCC:  0.8536
# Nash Sutcliffe Efficiency:  0.7505
# Mean Theta:  1.1858
# Median Theta:  1.0
# Processing for nfold  4 1
# MAE:  0.0308
# Bias:  0.0024
# RMSE:  0.038
# Normalized RMSE:  0.3873
# Normalized ROOT MEDIAN SE:  0.2623
# Unbiased RMSE:  0.038
# r:  0.9295
# r^2:  0.864
# R^2:  0.85
# Lin's CCC:  0.9101
# Nash Sutcliffe Efficiency:  0.85
# Mean Theta:  0.8783
# Median Theta:  0.0
# Processing for nfold  4 2
# MAE:  0.0308
# Bias:  -0.0009
# RMSE:  0.0378
# Normalized RMSE:  0.3971
# Normalized ROOT MEDIAN SE:  0.2875
# Unbiased RMSE:  0.0378
# r:  0.9179
# r^2:  0.8425
# R^2:  0.8423
# Lin's CCC:  0.9135
# Nash Sutcliffe Efficiency:  0.8423
# Mean Theta:  0.8686
# Median Theta:  0.0
# Processing for nfold  4 3
# MAE:  0.0341
# Bias:  0.0031
# RMSE:  0.0395
# Normalized RMSE:  0.4209
# Normalized ROOT MEDIAN SE:  0.3594
# Unbiased RMSE:  0.0394
# r:  0.9116
# r^2:  0.8309
# R^2:  0.8228
# Lin's CCC:  0.8955
# Nash Sutcliffe Efficiency:  0.8228
# Mean Theta:  0.9581
# Median Theta:  1.0
# Processing for nfold  5 1
# MAE:  0.0384
# Bias:  0.0058
# RMSE:  0.0454
# Normalized RMSE:  0.518
# Normalized ROOT MEDIAN SE:  0.4158
# Unbiased RMSE:  0.045
# r:  0.8611
# r^2:  0.7415
# R^2:  0.7317
# Lin's CCC:  0.8591
# Nash Sutcliffe Efficiency:  0.7317
# Mean Theta:  1.2847
# Median Theta:  1.0
# Processing for nfold  5 2
# MAE:  0.0398
# Bias:  -0.0182
# RMSE:  0.0507
# Normalized RMSE:  0.6123
# Normalized ROOT MEDIAN SE:  0.3885
# Unbiased RMSE:  0.0473
# r:  0.85
# r^2:  0.7224
# R^2:  0.6251
# Lin's CCC:  0.8479
# Nash Sutcliffe Efficiency:  0.6251
# Mean Theta:  1.6339
# Median Theta:  1.0
# Processing for nfold  5 3
# MAE:  0.0397
# Bias:  0.001
# RMSE:  0.0471
# Normalized RMSE:  0.5077
# Normalized ROOT MEDIAN SE:  0.3841
# Unbiased RMSE:  0.0471
# r:  0.8616
# r^2:  0.7424
# R^2:  0.7423
# Lin's CCC:  0.8522
# Nash Sutcliffe Efficiency:  0.7423
# Mean Theta:  1.3921
# Median Theta:  1.0
# Saving all predictions in dataframe ...
# ---- X-validation Summary -----
# Mean MAE: 0.034 +/- 0.005
# Mean Bias: -0.0 +/- 0.007
# Mean RMSE: 0.042 +/- 0.006
# Mean unbiased RMSE: 0.042 +/- 0.006
# Mean normalized RMSE: 0.473 +/- 0.111
# Median normalized RMSE: 0.376
# Mean r: 0.892 +/- 0.048
# Mean r^2: 0.797
# Mean R^2: 0.764
# Mean LCCC: 0.878
# Mean NSE: 0.764
# Mean Theta: 1.13 +/- 0.353
# Time elapsed: 0.010437043772803413 hours.)
# All output files of blr saved in results_testmodel_gapfill/Xval_5_3-fold_blr_SM
#
# Computing 5_3-fold xrossvalidation for function model: xgb
# Processing for nfold  1 1
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0149
# Bias:  -0.002
# RMSE:  0.0209
# Normalized RMSE:  0.2645
# Normalized ROOT MEDIAN SE:  0.1301
# Unbiased RMSE:  0.0208
# r:  0.9676
# r^2:  0.9363
# R^2:  0.9301
# Lin's CCC:  0.9668
# Nash Sutcliffe Efficiency:  0.9301
# Mean Theta:  437031356.0639
# Median Theta:  105794155.0
# Processing for nfold  1 2
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0217
# Bias:  0.0021
# RMSE:  0.0302
# Normalized RMSE:  0.3865
# Normalized ROOT MEDIAN SE:  0.1893
# Unbiased RMSE:  0.0301
# r:  0.9233
# r^2:  0.8526
# R^2:  0.8506
# Lin's CCC:  0.9225
# Nash Sutcliffe Efficiency:  0.8506
# Mean Theta:  913200710.1117
# Median Theta:  218932739.0
# Processing for nfold  1 3
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0164
# Bias:  -0.0034
# RMSE:  0.0223
# Normalized RMSE:  0.2795
# Normalized ROOT MEDIAN SE:  0.1521
# Unbiased RMSE:  0.0221
# r:  0.9616
# r^2:  0.9247
# R^2:  0.9219
# Lin's CCC:  0.9616
# Nash Sutcliffe Efficiency:  0.9219
# Mean Theta:  498357653.3365
# Median Theta:  147598806.0
# Processing for nfold  2 1
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0126
# Bias:  -0.0021
# RMSE:  0.0165
# Normalized RMSE:  0.1496
# Normalized ROOT MEDIAN SE:  0.0902
# Unbiased RMSE:  0.0163
# r:  0.9906
# r^2:  0.9813
# R^2:  0.9776
# Lin's CCC:  0.9882
# Nash Sutcliffe Efficiency:  0.9776
# Mean Theta:  270732636.7829
# Median Theta:  98435030.0
# Processing for nfold  2 2
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.014
# Bias:  0.0067
# RMSE:  0.0196
# Normalized RMSE:  0.1882
# Normalized ROOT MEDIAN SE:  0.0944
# Unbiased RMSE:  0.0184
# r:  0.9845
# r^2:  0.9693
# R^2:  0.9646
# Lin's CCC:  0.9838
# Nash Sutcliffe Efficiency:  0.9646
# Mean Theta:  382502318.2033
# Median Theta:  96323244.0
# Processing for nfold  2 3
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0175
# Bias:  -0.0102
# RMSE:  0.0222
# Normalized RMSE:  0.2155
# Normalized ROOT MEDIAN SE:  0.145
# Unbiased RMSE:  0.0198
# r:  0.9817
# r^2:  0.9638
# R^2:  0.9536
# Lin's CCC:  0.9817
# Nash Sutcliffe Efficiency:  0.9536
# Mean Theta:  495027680.0035
# Median Theta:  224187105.0
# Processing for nfold  3 1
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.021
# Bias:  -0.0062
# RMSE:  0.0265
# Normalized RMSE:  0.2998
# Normalized ROOT MEDIAN SE:  0.2071
# Unbiased RMSE:  0.0258
# r:  0.9626
# r^2:  0.9266
# R^2:  0.9101
# Lin's CCC:  0.9509
# Nash Sutcliffe Efficiency:  0.9101
# Mean Theta:  704468056.7674
# Median Theta:  336204876.0
# Processing for nfold  3 2
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.023
# Bias:  0.0048
# RMSE:  0.0343
# Normalized RMSE:  0.3987
# Normalized ROOT MEDIAN SE:  0.1651
# Unbiased RMSE:  0.034
# r:  0.9188
# r^2:  0.8442
# R^2:  0.8411
# Lin's CCC:  0.9149
# Nash Sutcliffe Efficiency:  0.8411
# Mean Theta:  1179832109.0443
# Median Theta:  202312981.0
# Processing for nfold  3 3
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0262
# Bias:  0.0158
# RMSE:  0.0355
# Normalized RMSE:  0.4057
# Normalized ROOT MEDIAN SE:  0.2272
# Unbiased RMSE:  0.0318
# r:  0.9349
# r^2:  0.8741
# R^2:  0.8354
# Lin's CCC:  0.9239
# Nash Sutcliffe Efficiency:  0.8354
# Mean Theta:  1259185975.946
# Median Theta:  394821420.0
# Processing for nfold  4 1
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0197
# Bias:  0.0081
# RMSE:  0.0259
# Normalized RMSE:  0.2639
# Normalized ROOT MEDIAN SE:  0.1457
# Unbiased RMSE:  0.0246
# r:  0.97
# r^2:  0.9409
# R^2:  0.9304
# Lin's CCC:  0.9655
# Nash Sutcliffe Efficiency:  0.9304
# Mean Theta:  671263444.3891
# Median Theta:  204557244.0
# Processing for nfold  4 2
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0183
# Bias:  0.0011
# RMSE:  0.0289
# Normalized RMSE:  0.3033
# Normalized ROOT MEDIAN SE:  0.1091
# Unbiased RMSE:  0.0289
# r:  0.9532
# r^2:  0.9086
# R^2:  0.908
# Lin's CCC:  0.9509
# Nash Sutcliffe Efficiency:  0.908
# Mean Theta:  834551599.8252
# Median Theta:  107918929.0
# Processing for nfold  4 3
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0154
# Bias:  0.0017
# RMSE:  0.0224
# Normalized RMSE:  0.2383
# Normalized ROOT MEDIAN SE:  0.1023
# Unbiased RMSE:  0.0223
# r:  0.972
# r^2:  0.9448
# R^2:  0.9432
# Lin's CCC:  0.9699
# Nash Sutcliffe Efficiency:  0.9432
# Mean Theta:  499845339.8271
# Median Theta:  92168350.0
# Processing for nfold  5 1
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.021
# Bias:  0.0051
# RMSE:  0.0268
# Normalized RMSE:  0.3058
# Normalized ROOT MEDIAN SE:  0.19
# Unbiased RMSE:  0.0263
# r:  0.9569
# r^2:  0.9156
# R^2:  0.9065
# Lin's CCC:  0.9493
# Nash Sutcliffe Efficiency:  0.9065
# Mean Theta:  717799639.0305
# Median Theta:  277043371.0
# Processing for nfold  5 2
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0223
# Bias:  -0.0118
# RMSE:  0.033
# Normalized RMSE:  0.399
# Normalized ROOT MEDIAN SE:  0.1693
# Unbiased RMSE:  0.0308
# r:  0.9352
# r^2:  0.8746
# R^2:  0.8408
# Lin's CCC:  0.9341
# Nash Sutcliffe Efficiency:  0.8408
# Mean Theta:  1089642193.5341
# Median Theta:  196106575.0
# Processing for nfold  5 3
# Using default hyperparameters for XGBoosting
# {'n_estimators': 1000, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_leaves': 0, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# MAE:  0.0285
# Bias:  0.0081
# RMSE:  0.0391
# Normalized RMSE:  0.4216
# Normalized ROOT MEDIAN SE:  0.2325
# Unbiased RMSE:  0.0383
# r:  0.9234
# r^2:  0.8526
# R^2:  0.8223
# Lin's CCC:  0.8935
# Nash Sutcliffe Efficiency:  0.8223
# Mean Theta:  1528894917.1937
# Median Theta:  465202748.0
# Saving all predictions in dataframe ...
# ---- X-validation Summary -----
# Mean MAE: 0.02 +/- 0.004
# Mean Bias: 0.001 +/- 0.007
# Mean RMSE: 0.027 +/- 0.006
# Mean unbiased RMSE: 0.026 +/- 0.006
# Mean normalized RMSE: 0.301 +/- 0.082
# Median normalized RMSE: 0.152
# Mean r: 0.956 +/- 0.023
# Mean r^2: 0.914
# Mean R^2: 0.902
# Mean LCCC: 0.951
# Mean NSE: 0.902
# Mean Theta: 765489042.004 +/- 352057533.059
# Time elapsed: 0.011091681255234612 hours.)
# All output files of xgb saved in results_testmodel_gapfill/Xval_5_3-fold_xgb_SM

# %%
for model_function, stats_summary in zip(settings.model_functions, stats_summaries):
    print(f'--- {model_function} ---')
    for key, value in stats_summary.items():
        print(f'{key}:\t{value[0]}\t\u00b1 {value[1]}')
# Out:
# --- rf ---
# MAE:	0.022	± 0.004
# Bias:	-0.0	± 0.007
# RMSE:	0.029	± 0.005
# ubRMSE:	0.028	± 0.004
# nRMSE:	0.325	± 0.075
# r:	0.95	± 0.024
# r2:	0.904	± 0.044
# R2:	0.889	± 0.049
# LCCC:	0.941	± 0.026
# NSE:	0.889	± 0.049
# Theta:	0.705	± 0.378
# --- blr ---
# MAE:	0.034	± 0.005
# Bias:	-0.0	± 0.007
# RMSE:	0.042	± 0.006
# ubRMSE:	0.042	± 0.006
# nRMSE:	0.473	± 0.111
# r:	0.892	± 0.048
# r2:	0.797	± 0.086
# R2:	0.764	± 0.102
# LCCC:	0.878	± 0.043
# NSE:	0.764	± 0.102
# Theta:	1.13	± 0.353
# --- xgb ---
# MAE:	0.02	± 0.004
# Bias:	0.001	± 0.007
# RMSE:	0.027	± 0.006
# ubRMSE:	0.026	± 0.006
# nRMSE:	0.301	± 0.082
# r:	0.956	± 0.023
# r2:	0.914	± 0.043
# R2:	0.902	± 0.05
# LCCC:	0.951	± 0.027
# NSE:	0.902	± 0.05
# Theta:	765489042.004	± 352057533.059

# %%
from datetime import datetime
datetime.now().strftime("%Y-%m-%d %H:%M")
# Out:
# '2025-06-03 10:20'
